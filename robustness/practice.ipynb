# %%
import torch

ckpt = torch.load(
    "/davinci-1/home/lorenrossi/fiorire/model.pt",
    map_location="cpu",
    weights_only=False
)

print(type(ckpt))
print(ckpt.keys())
# Out:
# <class 'dict'>
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict', 'loss', 'loss_value', 'cfg', 'scaler_params_pre_training', 'scaler_params_fine_tuning', 'parameters_number', 'param_conf', 'metric_score', 'data_path', 'indices_path', 'scaler_path', 'metric_dataset_path', 'indices'])

# %%
def explore(d, indent=0):
    for k, v in d.items():
        print("  " * indent + f"- {k}: {type(v)}")
        if isinstance(v, dict):
            explore(v, indent + 1)

explore(ckpt)
# Out:
# - epoch: <class 'int'>
# - model_state_dict: <class 'collections.OrderedDict'>
#   - encoder.encoder.enc_lay_1.0.weight: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.0.bias: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.1.weight: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.1.bias: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.1.running_mean: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.1.running_var: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_1.1.num_batches_tracked: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.0.weight: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.0.bias: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.1.weight: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.1.bias: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.1.running_mean: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.1.running_var: <class 'torch.Tensor'>
#   - encoder.encoder.enc_lay_2.1.num_batches_tracked: <class 'torch.Tensor'>
#   - encoder.bottleneck.to_latent.weight: <class 'torch.Tensor'>
#   - encoder.bottleneck.to_latent.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.latent_to_flatten.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.latent_to_flatten.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm_1d.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm_1d.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm_1d.running_mean: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm_1d.running_var: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm_1d.num_batches_tracked: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.deconv.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.deconv.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm.running_mean: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm.running_var: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.batch_norm.num_batches_tracked: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.refine_conv.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_1.refine_conv.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.deconv.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.deconv.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.batch_norm.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.batch_norm.bias: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.batch_norm.running_mean: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.batch_norm.running_var: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.batch_norm.num_batches_tracked: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.refine_conv.weight: <class 'torch.Tensor'>
#   - decoder.decoder.dec_lay_2.refine_conv.bias: <class 'torch.Tensor'>
#   - decoder.decoder_out.weight: <class 'torch.Tensor'>
#   - decoder.decoder_out.bias: <class 'torch.Tensor'>
# - optimizer_state_dict: <class 'dict'>
#   - state: <class 'dict'>
#     - 0: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 1: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 2: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 3: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 4: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 5: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 6: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 7: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 8: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 9: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 10: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 11: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 12: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 13: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 14: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 15: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 16: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 17: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 18: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 19: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 20: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 21: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 22: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 23: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 24: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 25: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 26: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#     - 27: <class 'dict'>
#       - step: <class 'torch.Tensor'>
#       - exp_avg: <class 'torch.Tensor'>
#       - exp_avg_sq: <class 'torch.Tensor'>
#   - param_groups: <class 'list'>
# - loss: <class 'str'>
# - loss_value: <class 'float'>
# - cfg: <class 'omegaconf.dictconfig.DictConfig'>
# - scaler_params_pre_training: <class 'dict'>
#   - type: <class 'str'>
#   - mean_: <class 'list'>
#   - scale_: <class 'list'>
#   - var_: <class 'list'>
#   - n_samples_seen_: <class 'int'>
# - scaler_params_fine_tuning: <class 'NoneType'>
# - parameters_number: <class 'int'>
# - param_conf: <class 'int'>
# - metric_score: <class 'NoneType'>
# - data_path: <class 'str'>
# - indices_path: <class 'str'>
# - scaler_path: <class 'str'>
# - metric_dataset_path: <class 'str'>
# - indices: <class 'NoneType'>

# %%
import torch
from omegaconf import DictConfig, ListConfig, OmegaConf
from dataclasses import is_dataclass, asdict

def explore_any(obj, indent=0, max_depth=50, max_items=50):
    prefix = "  " * indent

    if indent > max_depth:
        print(prefix + "… (max depth reached)")
        return

    # --- dict ---
    if isinstance(obj, dict):
        print(prefix + f"dict ({len(obj)} keys)")
        for i, (k, v) in enumerate(obj.items()):
            if i >= max_items:
                print(prefix + "  … (more keys)")
                break
            print(prefix + f"- {k}: {type(v).__name__}")
            explore_any(v, indent + 1, max_depth, max_items)

    # --- list / tuple ---
    elif isinstance(obj, (list, tuple)):
        print(prefix + f"{type(obj).__name__} (len={len(obj)})")
        for i, v in enumerate(obj):
            if i >= max_items:
                print(prefix + "  … (more items)")
                break
            print(prefix + f"- [{i}]: {type(v).__name__}")
            explore_any(v, indent + 1, max_depth, max_items)

    # --- torch tensor ---
    elif torch.is_tensor(obj):
        print(prefix + f"Tensor shape={tuple(obj.shape)}, dtype={obj.dtype}, device={obj.device}")

    # --- OmegaConf ---
    elif isinstance(obj, (DictConfig, ListConfig)):
        print(prefix + f"{type(obj).__name__}")
        container = OmegaConf.to_container(obj, resolve=False)
        explore_any(container, indent + 1, max_depth, max_items)

    # --- dataclass ---
    elif is_dataclass(obj):
        print(prefix + f"dataclass {type(obj).__name__}")
        explore_any(asdict(obj), indent + 1, max_depth, max_items)

    # --- fallback ---
    else:
        val = repr(obj)
        if len(val) > 120:
            val = val[:120] + "…"
        print(prefix + f"value = {val}")

# %%
explore_any(ckpt)
# Out:
# dict (16 keys)
# - epoch: int
#   value = 51
# - model_state_dict: OrderedDict
#   dict (43 keys)
#   - encoder.encoder.enc_lay_1.0.weight: Tensor
#     Tensor shape=(32, 1, 7, 7), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.0.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.1.weight: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.1.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.1.running_mean: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.1.running_var: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_1.1.num_batches_tracked: Tensor
#     Tensor shape=(), dtype=torch.int64, device=cpu
#   - encoder.encoder.enc_lay_2.0.weight: Tensor
#     Tensor shape=(64, 32, 7, 7), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.0.bias: Tensor
#     Tensor shape=(64,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.1.weight: Tensor
#     Tensor shape=(64,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.1.bias: Tensor
#     Tensor shape=(64,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.1.running_mean: Tensor
#     Tensor shape=(64,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.1.running_var: Tensor
#     Tensor shape=(64,), dtype=torch.float32, device=cpu
#   - encoder.encoder.enc_lay_2.1.num_batches_tracked: Tensor
#     Tensor shape=(), dtype=torch.int64, device=cpu
#   - encoder.bottleneck.to_latent.weight: Tensor
#     Tensor shape=(76, 1024), dtype=torch.float32, device=cpu
#   - encoder.bottleneck.to_latent.bias: Tensor
#     Tensor shape=(76,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.latent_to_flatten.weight: Tensor
#     Tensor shape=(1024, 76), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.latent_to_flatten.bias: Tensor
#     Tensor shape=(1024,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm_1d.weight: Tensor
#     Tensor shape=(1024,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm_1d.bias: Tensor
#     Tensor shape=(1024,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm_1d.running_mean: Tensor
#     Tensor shape=(1024,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm_1d.running_var: Tensor
#     Tensor shape=(1024,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm_1d.num_batches_tracked: Tensor
#     Tensor shape=(), dtype=torch.int64, device=cpu
#   - decoder.decoder.dec_lay_1.deconv.weight: Tensor
#     Tensor shape=(64, 32, 2, 2), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.deconv.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm.weight: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm.running_mean: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm.running_var: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.batch_norm.num_batches_tracked: Tensor
#     Tensor shape=(), dtype=torch.int64, device=cpu
#   - decoder.decoder.dec_lay_1.refine_conv.weight: Tensor
#     Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_1.refine_conv.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.deconv.weight: Tensor
#     Tensor shape=(32, 32, 2, 2), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.deconv.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.batch_norm.weight: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.batch_norm.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.batch_norm.running_mean: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.batch_norm.running_var: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.batch_norm.num_batches_tracked: Tensor
#     Tensor shape=(), dtype=torch.int64, device=cpu
#   - decoder.decoder.dec_lay_2.refine_conv.weight: Tensor
#     Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#   - decoder.decoder.dec_lay_2.refine_conv.bias: Tensor
#     Tensor shape=(32,), dtype=torch.float32, device=cpu
#   - decoder.decoder_out.weight: Tensor
#     Tensor shape=(1, 32, 1, 1), dtype=torch.float32, device=cpu
#   - decoder.decoder_out.bias: Tensor
#     Tensor shape=(1,), dtype=torch.float32, device=cpu
# - optimizer_state_dict: dict
#   dict (2 keys)
#   - state: dict
#     dict (28 keys)
#     - 0: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32, 1, 7, 7), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32, 1, 7, 7), dtype=torch.float32, device=cpu
#     - 1: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 2: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 3: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 4: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(64, 32, 7, 7), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(64, 32, 7, 7), dtype=torch.float32, device=cpu
#     - 5: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#     - 6: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#     - 7: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(64,), dtype=torch.float32, device=cpu
#     - 8: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1024, 76), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1024, 76), dtype=torch.float32, device=cpu
#     - 9: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#     - 10: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#     - 11: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1024,), dtype=torch.float32, device=cpu
#     - 12: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(64, 32, 2, 2), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(64, 32, 2, 2), dtype=torch.float32, device=cpu
#     - 13: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 14: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 15: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 16: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#     - 17: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 18: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32, 32, 2, 2), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32, 32, 2, 2), dtype=torch.float32, device=cpu
#     - 19: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 20: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 21: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 22: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32, 32, 7, 7), dtype=torch.float32, device=cpu
#     - 23: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(32,), dtype=torch.float32, device=cpu
#     - 24: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1, 32, 1, 1), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1, 32, 1, 1), dtype=torch.float32, device=cpu
#     - 25: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(1,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(1,), dtype=torch.float32, device=cpu
#     - 26: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(76, 1024), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(76, 1024), dtype=torch.float32, device=cpu
#     - 27: dict
#       dict (3 keys)
#       - step: Tensor
#         Tensor shape=(), dtype=torch.float32, device=cpu
#       - exp_avg: Tensor
#         Tensor shape=(76,), dtype=torch.float32, device=cpu
#       - exp_avg_sq: Tensor
#         Tensor shape=(76,), dtype=torch.float32, device=cpu
#   - param_groups: list
#     list (len=1)
#     - [0]: dict
#       dict (12 keys)
#       - lr: float
#         value = 0.0004096000000000001
#       - name: str
#         value = 'main'
#       - betas: tuple
#         tuple (len=2)
#         - [0]: float
#           value = 0.9
#         - [1]: float
#           value = 0.999
#       - eps: float
#         value = 1e-08
#       - weight_decay: int
#         value = 0
#       - amsgrad: bool
#         value = False
#       - maximize: bool
#         value = False
#       - foreach: NoneType
#         value = None
#       - capturable: bool
#         value = False
#       - differentiable: bool
#         value = False
#       - fused: bool
#         value = False
#       - params: list
#         list (len=28)
#         - [0]: int
#           value = 0
#         - [1]: int
#           value = 1
#         - [2]: int
#           value = 2
#         - [3]: int
#           value = 3
#         - [4]: int
#           value = 4
#         - [5]: int
#           value = 5
#         - [6]: int
#           value = 6
#         - [7]: int
#           value = 7
#         - [8]: int
#           value = 8
#         - [9]: int
#           value = 9
#         - [10]: int
#           value = 10
#         - [11]: int
#           value = 11
#         - [12]: int
#           value = 12
#         - [13]: int
#           value = 13
#         - [14]: int
#           value = 14
#         - [15]: int
#           value = 15
#         - [16]: int
#           value = 16
#         - [17]: int
#           value = 17
#         - [18]: int
#           value = 18
#         - [19]: int
#           value = 19
#         - [20]: int
#           value = 20
#         - [21]: int
#           value = 21
#         - [22]: int
#           value = 22
#         - [23]: int
#           value = 23
#         - [24]: int
#           value = 24
#         - [25]: int
#           value = 25
#         - [26]: int
#           value = 26
#         - [27]: int
#           value = 27
# - loss: str
#   value = 'val_roc_auc'
# - loss_value: float
#   value = 0.8250759794928071
# - cfg: DictConfig
#   DictConfig
#     dict (5 keys)
#     - tune_config: dict
#       dict (24 keys)
#       - model.num_layers: str
#         value = 'tune.choice([2, 3])'
#       - model.base_filters: str
#         value = 'tune.choice([16,32,64,86])'
#       - model.activation: str
#         value = "tune.choice(['Relu'])"
#       - model.kernel_size: str
#         value = 'tune.choice([3,5,7, 9])'
#       - model.bottleneck_conv: str
#         value = 'tune.choice([0, 1])'
#       - model.double_deconv: str
#         value = 'tune.choice([1])'
#       - model.decoder_mode: str
#         value = "tune.choice(['base_filters', 'progressive'])"
#       - model.compression_factor: str
#         value = 'tune.choice([1, 2, 3, 4])'
#       - model.compression_factor_on_inputs: str
#         value = 'tune.choice([4, 8, 16, 32, 64, 128])'
#       - model.halve_both: str
#         value = 'tune.choice([1])'
#       - model.halve_time: str
#         value = 'tune.choice([0])'
#       - model.halve_features: str
#         value = 'tune.choice([0])'
#       - model.flattened: str
#         value = 'tune.choice([1])'
#       - model.increasing: str
#         value = 'tune.choice([1])'
#       - model.pool: str
#         value = 'tune.choice([1])'
#       - model.stride: str
#         value = 'tune.choice([1])'
#       - model.dilation: str
#         value = 'tune.choice([1])'
#       - opt.config_file_path: str
#         value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/tune.choice(["conv_ae2D_CMG.yaml"])'
#       - opt.lr: str
#         value = 'tune.choice([0.0001, 0.0009, 0.001, 0.0003])'
#       - opt.batch_size: str
#         value = 'tune.choice([300, 500, 800])'
#       - opt.epochs: str
#         value = 'tune.choice([300])'
#       - opt.lr_patience: str
#         value = 'tune.choice([5, 10, 15])'
#       - opt.es_patience: str
#         value = 'tune.choice([10])'
#       - dataset.perc_overlap: str
#         value = 'tune.choice([0.8])'
#     - dataset: dict
#       dict (22 keys)
#       - seed: int
#         value = 42
#       - name: str
#         value = 'fiorire_2_CMG'
#       - upsample_factor: int
#         value = 1
#       - upsample_method: str
#         value = 'linear'
#       - upsample_augmentation: int
#         value = 0
#       - seq_in_length: int
#         value = 16
#       - val_overlap: int
#         value = 0
#       - scaler: str
#         value = 'StandardScaler'
#       - data_path: str
#         value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/data/fiorire_2/AllScenarios_CMG.csv'
#       - seq_in_length_into_chunk: int
#         value = 200
#       - seq_out_length: int
#         value = 16
#       - train_val_split: float
#         value = 0.8
#       - shuffle_train: bool
#         value = True
#       - feats: list
#         list (len=19)
#         - [0]: str
#           value = 'ACT40101(MODEMNG_CMG_TORQUE_REQ_X)'
#         - [1]: str
#           value = 'ACT40102(MODEMNG_CMG_TORQUE_REQ_Y)'
#         - [2]: str
#           value = 'ACT40103(MODEMNG_CMG_TORQUE_REQ_Z)'
#         - [3]: str
#           value = 'ACT41027(UNIT_FW_VEL_1)'
#         - [4]: str
#           value = 'ACT41028(UNIT_FW_VEL_2)'
#         - [5]: str
#           value = 'ACT41029(UNIT_FW_VEL_3)'
#         - [6]: str
#           value = 'ACT41037(UNIT_GIMB_POS_1)'
#         - [7]: str
#           value = 'ACT41038(UNIT_GIMB_POS_2)'
#         - [8]: str
#           value = 'ACT41039(UNIT_GIMB_POS_3)'
#         - [9]: str
#           value = 'ACT41042(UNIT_GIMB_VEL_1)'
#         - [10]: str
#           value = 'ACT41043(UNIT_GIMB_VEL_2)'
#         - [11]: str
#           value = 'ACT41044(UNIT_GIMB_VEL_3)'
#         - [12]: str
#           value = 'ACT41052(ASSEMBLY_H_BRF_X)'
#         - [13]: str
#           value = 'ACT41053(ASSEMBLY_H_BRF_Y)'
#         - [14]: str
#           value = 'ACT41054(ASSEMBLY_H_BRF_Z)'
#         - [15]: str
#           value = 'ACT41056(ASSEMBLY_T_BRF_X)'
#         - [16]: str
#           value = 'ACT41057(ASSEMBLY_T_BRF_Y)'
#         - [17]: str
#           value = 'ACT41058(ASSEMBLY_T_BRF_Z)'
#         - [18]: str
#           value = 'ACT40001(PREPRO_CMG_LEVEL)'
#       - target: list
#         list (len=19)
#         - [0]: str
#           value = 'ACT40101(MODEMNG_CMG_TORQUE_REQ_X)'
#         - [1]: str
#           value = 'ACT40102(MODEMNG_CMG_TORQUE_REQ_Y)'
#         - [2]: str
#           value = 'ACT40103(MODEMNG_CMG_TORQUE_REQ_Z)'
#         - [3]: str
#           value = 'ACT41027(UNIT_FW_VEL_1)'
#         - [4]: str
#           value = 'ACT41028(UNIT_FW_VEL_2)'
#         - [5]: str
#           value = 'ACT41029(UNIT_FW_VEL_3)'
#         - [6]: str
#           value = 'ACT41037(UNIT_GIMB_POS_1)'
#         - [7]: str
#           value = 'ACT41038(UNIT_GIMB_POS_2)'
#         - [8]: str
#           value = 'ACT41039(UNIT_GIMB_POS_3)'
#         - [9]: str
#           value = 'ACT41042(UNIT_GIMB_VEL_1)'
#         - [10]: str
#           value = 'ACT41043(UNIT_GIMB_VEL_2)'
#         - [11]: str
#           value = 'ACT41044(UNIT_GIMB_VEL_3)'
#         - [12]: str
#           value = 'ACT41052(ASSEMBLY_H_BRF_X)'
#         - [13]: str
#           value = 'ACT41053(ASSEMBLY_H_BRF_Y)'
#         - [14]: str
#           value = 'ACT41054(ASSEMBLY_H_BRF_Z)'
#         - [15]: str
#           value = 'ACT41056(ASSEMBLY_T_BRF_X)'
#         - [16]: str
#           value = 'ACT41057(ASSEMBLY_T_BRF_Y)'
#         - [17]: str
#           value = 'ACT41058(ASSEMBLY_T_BRF_Z)'
#         - [18]: str
#           value = 'ACT40001(PREPRO_CMG_LEVEL)'
#       - remove_target: bool
#         value = False
#       - dataset_subset: NoneType
#         value = None
#       - save_dataloaders: bool
#         value = False
#       - forecast: bool
#         value = False
#       - is_anomaly_column: str
#         value = 'is_anomaly'
#       - perc_overlap: float
#         value = 0.8
#       - n_features: int
#         value = 19
#     - model: dict
#       dict (23 keys)
#       - name: str
#         value = 'conv_ae2D'
#       - aux_channels: int
#         value = 1
#       - checkpoint_path: NoneType
#         value = None
#       - bottleneck_conv: int
#         value = 0
#       - decoder_mode: str
#         value = 'base_filters'
#       - num_layers: int
#         value = 2
#       - base_filters: int
#         value = 32
#       - activation: str
#         value = 'Relu'
#       - kernel_size: int
#         value = 7
#       - double_deconv: int
#         value = 1
#       - compression_factor: int
#         value = 3
#       - compression_factor_on_inputs: int
#         value = 4
#       - halve_both: int
#         value = 1
#       - halve_time: int
#         value = 0
#       - halve_features: int
#         value = 0
#       - flattened: int
#         value = 1
#       - increasing: int
#         value = 1
#       - pool: int
#         value = 1
#       - stride: int
#         value = 1
#       - dilation: int
#         value = 1
#       - flattened_size: int
#         value = 1024
#       - latent_dim: int
#         value = 76
#       - parameter_count: int
#         value = 373933
#     - resources: dict
#       dict (2 keys)
#       - gpu_trial: int
#         value = 1
#       - cpu_trial: int
#         value = 12
#     - opt: dict
#       dict (27 keys)
#       - exp_name: str
#         value = 'CMG'
#       - seed: int
#         value = 42
#       - opt_metric: dict
#         dict (1 keys)
#         - val_roc_auc: str
#           value = 'max'
#       - metrics_to_report: list
#         list (len=11)
#         - [0]: str
#           value = 'train_loss'
#         - [1]: str
#           value = 'val_loss'
#         - [2]: str
#           value = 'val_f1_score'
#         - [3]: str
#           value = 'best_val_f1_score'
#         - [4]: str
#           value = 'val_roc_auc'
#         - [5]: str
#           value = 'best_val_roc_auc'
#         - [6]: str
#           value = 'val_fpr'
#         - [7]: str
#           value = 'best_val_fpr'
#         - [8]: str
#           value = 'val_tpr'
#         - [9]: str
#           value = 'best_val_tpr'
#         - [10]: str
#           value = 'best_val_thresh_f1'
#       - other_reports: list
#         list (len=2)
#         - [0]: str
#           value = 'parameters_number'
#         - [1]: str
#           value = 'data_path'
#       - metric_seq_overlap: int
#         value = 0
#       - use_error: str
#         value = 'se'
#       - num_workers: int
#         value = 12
#       - anomalies_dataset_subset: NoneType
#         value = None
#       - num_thresholds: int
#         value = 100
#       - remove_columns: list
#         list (len=0)
#       - filter_anomalies: bool
#         value = True
#       - plot_metric_samples: bool
#         value = True
#       - plot_metric_percentage: float
#         value = 0.05
#       - anomaly_strategy: str
#         value = 'corrupt_validation'
#       - force_regenerate: bool
#         value = False
#       - evaluate_metrics: bool
#         value = True
#       - detect_anomaly_epoch_freq: int
#         value = 1
#       - max_epochs: int
#         value = 500
#       - corruption_config: dict
#         dict (6 keys)
#         - anomalies_type: list
#           list (len=4)
#           - [0]: str
#             value = 'GWN'
#           - [1]: str
#             value = 'Step'
#           - [2]: str
#             value = 'Impulse'
#           - [3]: str
#             value = 'Constant'
#         - delta_mean: float
#           value = 0.5
#         - min_channels: int
#           value = 1
#         - max_channels: int
#           value = 1
#         - corruption_ratio: int
#           value = 1
#         - random_seed: int
#           value = 123
#       - target_channels: NoneType
#         value = None
#       - config_file_path: str
#         value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/conv_ae2D_CMG.yaml'
#       - lr: float
#         value = 0.001
#       - batch_size: int
#         value = 300
#       - epochs: int
#         value = 300
#       - lr_patience: int
#         value = 10
#       - es_patience: int
#         value = 10
# - scaler_params_pre_training: dict
#   dict (5 keys)
#   - type: str
#     value = 'StandardScaler'
#   - mean_: list
#     list (len=19)
#     - [0]: float
#       value = 4.46762291962819e-06
#     - [1]: float
#       value = 1.7430191192662719e-06
#     - [2]: float
#       value = -4.2951607295125334e-08
#     - [3]: float
#       value = 295.4395250309811
#     - [4]: float
#       value = 295.4395250309811
#     - [5]: float
#       value = 295.4395250309811
#     - [6]: float
#       value = -6.585042134120338e-06
#     - [7]: float
#       value = 2.0402399602596484
#     - [8]: float
#       value = 2.1455333536671857
#     - [9]: float
#       value = -1.3074490175999513e-06
#     - [10]: float
#       value = 3.3927057789704077e-06
#     - [11]: float
#       value = 7.160983831745689e-06
#     - [12]: float
#       value = 0.0006045989337041603
#     - [13]: float
#       value = 0.16441705089374845
#     - [14]: float
#       value = 0.0013497699647559845
#     - [15]: float
#       value = -6.392453935763527e-06
#     - [16]: float
#       value = 5.322576073374687e-06
#     - [17]: float
#       value = -5.427934182359613e-06
#     - [18]: float
#       value = 0.6207596475895277
#   - scale_: list
#     list (len=19)
#     - [0]: float
#       value = 0.004418296685553948
#     - [1]: float
#       value = 0.003051963415287327
#     - [2]: float
#       value = 0.002570027966436735
#     - [3]: float
#       value = 44.69966793917005
#     - [4]: float
#       value = 44.69966793917005
#     - [5]: float
#       value = 44.69966793917005
#     - [6]: float
#       value = 0.04110865710281314
#     - [7]: float
#       value = 0.07254495297249756
#     - [8]: float
#       value = 0.08105021352133632
#     - [9]: float
#       value = 0.001659008023202372
#     - [10]: float
#       value = 0.0014011485705043066
#     - [11]: float
#       value = 0.00145120244870323
#     - [12]: float
#       value = 0.12060899776160103
#     - [13]: float
#       value = 0.07062679624039453
#     - [14]: float
#       value = 0.09526977979823456
#     - [15]: float
#       value = 0.004455152112473694
#     - [16]: float
#       value = 0.0029969951416247997
#     - [17]: float
#       value = 0.0026367212198106665
#     - [18]: float
#       value = 0.09399341303322682
#   - var_: list
#     list (len=19)
#     - [0]: float
#       value = 1.9521345601577008e-05
#     - [1]: float
#       value = 9.314480688252287e-06
#     - [2]: float
#       value = 6.6050437482669375e-06
#     - [3]: float
#       value = 1998.0603138720664
#     - [4]: float
#       value = 1998.0603138720664
#     - [5]: float
#       value = 1998.0603138720664
#     - [6]: float
#       value = 0.0016899216887966695
#     - [7]: float
#       value = 0.005262770201781883
#     - [8]: float
#       value = 0.006569137111854207
#     - [9]: float
#       value = 2.7523076210498414e-06
#     - [10]: float
#       value = 1.963217316626262e-06
#     - [11]: float
#       value = 2.1059885471222505e-06
#     - [12]: float
#       value = 0.014546530341057882
#     - [13]: float
#       value = 0.004988144347182207
#     - [14]: float
#       value = 0.009076330942804101
#     - [15]: float
#       value = 1.9848380345278815e-05
#     - [16]: float
#       value = 8.981979878922652e-06
#     - [17]: float
#       value = 6.95229879099985e-06
#     - [18]: float
#       value = 0.008834761693634775
#   - n_samples_seen_: int
#     value = 921085
# - scaler_params_fine_tuning: NoneType
#   value = None
# - parameters_number: int
#   value = 373933
# - param_conf: int
#   value = 373933
# - metric_score: NoneType
#   value = None
# - data_path: str
#   value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/data/fiorire_2/AllScenarios_CMG.csv'
# - indices_path: str
#   value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/train_val_indices/conv_ae2D_CMG_fiorire_2_CMG_seed42_fil…
# - scaler_path: str
#   value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/train_val_indices/conv_ae2D_CMG_fiorire_2_CMG_seed42_fil…
# - metric_dataset_path: str
#   value = '/davinci-1/home/morellir/artificial_intelligence/repos/fiorire/metric_datasets/metric_conv_ae2D_CMG_fiorire_2_CMG_corru…
# - indices: NoneType
#   value = None
